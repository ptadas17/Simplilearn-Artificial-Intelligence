# %%
# Importing libraries
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA


# Importing train.csv
df_train = pd.read_csv('train.csv')

print('Size of training set: {} rows and {} columns'.format(*df_train.shape))
print('-------------------------------------------------------------------------')

df_train.head()


# Collecting Y values in one array
y_train = df_train['y'].values


# Iterating through columns with X in their name
cols = [c for c in df_train.columns if 'X' in c]
print('Number of features: {}'.format(len(cols)))

print('Feature types:')
df_train[cols].dtypes.value_counts()

# Counting data in each columns
count = [[],[],[]]
for c in cols:
    typp = df_train[c].dtype
    unq = len(np.unique(df_train[c]))
    if unq == 1:
        count[0].append(c)
    elif unq == 2 and typp == np.int64:
        count[1].append(c)
    else:
        count[2].append(c)
        
print('Constant features: {} | Binary features: {} | Categorical features: {}\n'
      .format(*[len(c) for c in count]))
print('Constant features:', count[0]) #constant features can also be called as useless features
print('Categorical features:', count[2])
print('--------------------------------------------------------------------------')


# Importing test.csv
df_test = pd.read_csv('test.csv')

useful_columns = list(set(df_train.columns) - set(['ID', 'y']))
y_train = df_train['y'].values
id_test = df_test['ID'].values

x_train = df_train[useful_columns]
x_test = df_test[useful_columns]


# Checking for null and unique values in train and test datasets
def missing_values(df):
    if df.isnull().any().any():
        print('Missing values present')
    else:
        print('NO missing values present')

missing_values(x_train)
missing_values(x_test)


# For any columns, if variance is zero, remove that columns
# Apply LabelEncoder
for column in useful_columns:
    vari = len(np.unique(x_train[column]))
    if vari == 1:
        x_train.drop(column, axis=1)
        x_test.drop(column, axis=1)
    if vari > 2:
        map = lambda x: sum([ord(digit) for digit in x])
        x_train[column] = x_train[column].apply(map)
        x_test[column] = x_test[column].apply(map)
x_train.head

print('Feature types:')
x_train[cols].dtypes.value_counts()


# Perform Dimensionality Reduction
n_comp = 12
pca = PCA(n_components=n_comp, random_state=420)
pcat_results_train = pca.fit_transform(x_train)
pcat_results_test = pca.transform(x_test)


# XGBoost
import xgboost as xgb
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

x_train, x_validation, y_train, y_validation = train_test_split(pcat_results_train, y_train, test_size=0.2, random_state=4242)

d_train = xgb.DMatrix(x_train, label=y_train)
d_validation = xgb.DMatrix(x_validation, label=y_validation)
d_test = xgb.DMatrix(pcat_results_test)

params = {}
params['objective'] = 'reg:linear'
params['eta'] = 0.02
params['max_depth'] = 4

def xgb_r2_score(preds, dtrain):
    labels = dtrain.get_label()
    return 'r2', r2_score(labels, preds)

watchlist = [(d_train, 'train'), (d_validation, 'validation')]

clf = xgb.train(params, d_train,
                1000, watchlist, early_stopping_rounds=50,
                feval=xgb_r2_score, maximize=True, verbose_eval=10)



# Predict your df_test values using XGBoost
p_test = clf.predict(d_test)

sub = pd.DataFrame()
sub['ID'] = id_test
sub['y'] = p_test
sub.to_csv('xgb.csv', index=False)

sub.head()
# Out:
# Size of training set: 4209 rows and 378 columns
# -------------------------------------------------------------------------
# Number of features: 376
# Feature types:
# Constant features: 12 | Binary features: 356 | Categorical features: 8
#
# Constant features: ['X11', 'X93', 'X107', 'X233', 'X235', 'X268', 'X289', 'X290', 'X293', 'X297', 'X330', 'X347']
# Categorical features: ['X0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X8']
# --------------------------------------------------------------------------
# NO missing values present
# NO missing values present
# <ipython-input-9-d989ee012b97>:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train[column] = x_train[column].apply(map)
# <ipython-input-9-d989ee012b97>:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[column] = x_test[column].apply(map)
# Feature types:
# [00:56:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	train-rmse:99.14834	validation-rmse:98.26296	train-r2:-58.35295	validation-r2:-67.63754
# Multiple eval metrics have been passed: 'validation-r2' will be used for early stopping.
#
# Will train until validation-r2 hasn't improved in 50 rounds.
# [10]	train-rmse:81.27653	validation-rmse:80.36433	train-r2:-38.88428	validation-r2:-44.91014
# [20]	train-rmse:66.71610	validation-rmse:65.77334	train-r2:-25.87403	validation-r2:-29.75260
# [30]	train-rmse:54.86956	validation-rmse:53.88963	train-r2:-17.17751	validation-r2:-19.64393
# [40]	train-rmse:45.24492	validation-rmse:44.21995	train-r2:-11.35979	validation-r2:-12.90012
# [50]	train-rmse:37.44736	validation-rmse:36.37245	train-r2:-7.46669	validation-r2:-8.40431
# [60]	train-rmse:31.14760	validation-rmse:30.01883	train-r2:-4.85761	validation-r2:-5.40575
# [70]	train-rmse:26.08679	validation-rmse:24.90901	train-r2:-3.10878	validation-r2:-3.41057
# [80]	train-rmse:22.04667	validation-rmse:20.83109	train-r2:-1.93466	validation-r2:-2.08465
# [90]	train-rmse:18.84415	validation-rmse:17.60480	train-r2:-1.14400	validation-r2:-1.20315
# [100]	train-rmse:16.34039	validation-rmse:15.08374	train-r2:-0.61212	validation-r2:-0.61733
# [110]	train-rmse:14.40190	validation-rmse:13.14901	train-r2:-0.25231	validation-r2:-0.22905
# [120]	train-rmse:12.92208	validation-rmse:11.69020	train-r2:-0.00818	validation-r2:0.02854
# [130]	train-rmse:11.81356	validation-rmse:10.61646	train-r2:0.15738	validation-r2:0.19880
# [140]	train-rmse:10.98386	validation-rmse:9.84479	train-r2:0.27158	validation-r2:0.31104
# [150]	train-rmse:10.37675	validation-rmse:9.30919	train-r2:0.34988	validation-r2:0.38396
# [160]	train-rmse:9.93035	validation-rmse:8.95454	train-r2:0.40461	validation-r2:0.43001
# [170]	train-rmse:9.59063	validation-rmse:8.70868	train-r2:0.44465	validation-r2:0.46088
# [180]	train-rmse:9.34723	validation-rmse:8.55531	train-r2:0.47248	validation-r2:0.47970
# [190]	train-rmse:9.15963	validation-rmse:8.45268	train-r2:0.49344	validation-r2:0.49211
# [200]	train-rmse:9.01807	validation-rmse:8.38403	train-r2:0.50898	validation-r2:0.50033
# [210]	train-rmse:8.91628	validation-rmse:8.34517	train-r2:0.52000	validation-r2:0.50495
# [220]	train-rmse:8.84141	validation-rmse:8.32670	train-r2:0.52803	validation-r2:0.50714
# [230]	train-rmse:8.78794	validation-rmse:8.31459	train-r2:0.53372	validation-r2:0.50857
# [240]	train-rmse:8.74259	validation-rmse:8.30836	train-r2:0.53852	validation-r2:0.50930
# [250]	train-rmse:8.69698	validation-rmse:8.30280	train-r2:0.54332	validation-r2:0.50996
# [260]	train-rmse:8.66026	validation-rmse:8.30215	train-r2:0.54717	validation-r2:0.51004
# [270]	train-rmse:8.62238	validation-rmse:8.30106	train-r2:0.55112	validation-r2:0.51017
# [280]	train-rmse:8.59121	validation-rmse:8.30103	train-r2:0.55436	validation-r2:0.51017
# [290]	train-rmse:8.57180	validation-rmse:8.29925	train-r2:0.55637	validation-r2:0.51038
# [300]	train-rmse:8.54680	validation-rmse:8.29958	train-r2:0.55896	validation-r2:0.51034
# [310]	train-rmse:8.52444	validation-rmse:8.29788	train-r2:0.56126	validation-r2:0.51054
# [320]	train-rmse:8.50380	validation-rmse:8.29544	train-r2:0.56339	validation-r2:0.51083
# [330]	train-rmse:8.48037	validation-rmse:8.29575	train-r2:0.56579	validation-r2:0.51079
# [340]	train-rmse:8.45231	validation-rmse:8.29181	train-r2:0.56866	validation-r2:0.51126
# [350]	train-rmse:8.42699	validation-rmse:8.29384	train-r2:0.57124	validation-r2:0.51102
# [360]	train-rmse:8.40341	validation-rmse:8.29060	train-r2:0.57363	validation-r2:0.51140
# [370]	train-rmse:8.37703	validation-rmse:8.29011	train-r2:0.57631	validation-r2:0.51146
# [380]	train-rmse:8.35429	validation-rmse:8.28870	train-r2:0.57860	validation-r2:0.51162
# [390]	train-rmse:8.33333	validation-rmse:8.28745	train-r2:0.58072	validation-r2:0.51177
# [400]	train-rmse:8.30304	validation-rmse:8.28725	train-r2:0.58376	validation-r2:0.51179
# [410]	train-rmse:8.28437	validation-rmse:8.28607	train-r2:0.58563	validation-r2:0.51193
# [420]	train-rmse:8.25766	validation-rmse:8.28453	train-r2:0.58830	validation-r2:0.51211
# [430]	train-rmse:8.23761	validation-rmse:8.28291	train-r2:0.59029	validation-r2:0.51231
# [440]	train-rmse:8.21040	validation-rmse:8.28190	train-r2:0.59300	validation-r2:0.51242
# [450]	train-rmse:8.18634	validation-rmse:8.28040	train-r2:0.59538	validation-r2:0.51260
# [460]	train-rmse:8.15841	validation-rmse:8.28181	train-r2:0.59813	validation-r2:0.51243
# [470]	train-rmse:8.13633	validation-rmse:8.27976	train-r2:0.60031	validation-r2:0.51268
# [480]	train-rmse:8.11604	validation-rmse:8.27937	train-r2:0.60230	validation-r2:0.51272
# [490]	train-rmse:8.08497	validation-rmse:8.27662	train-r2:0.60534	validation-r2:0.51305
# [500]	train-rmse:8.06447	validation-rmse:8.27841	train-r2:0.60733	validation-r2:0.51284
# [510]	train-rmse:8.04068	validation-rmse:8.27812	train-r2:0.60965	validation-r2:0.51287
# [520]	train-rmse:8.02106	validation-rmse:8.27799	train-r2:0.61155	validation-r2:0.51288
# [530]	train-rmse:8.00504	validation-rmse:8.27944	train-r2:0.61310	validation-r2:0.51271
# [540]	train-rmse:7.98178	validation-rmse:8.27635	train-r2:0.61535	validation-r2:0.51308
# [550]	train-rmse:7.95451	validation-rmse:8.27670	train-r2:0.61797	validation-r2:0.51304
# [560]	train-rmse:7.93507	validation-rmse:8.27421	train-r2:0.61983	validation-r2:0.51333
# [570]	train-rmse:7.91111	validation-rmse:8.26996	train-r2:0.62213	validation-r2:0.51383
# [580]	train-rmse:7.89342	validation-rmse:8.27049	train-r2:0.62382	validation-r2:0.51377
# [590]	train-rmse:7.86614	validation-rmse:8.26850	train-r2:0.62641	validation-r2:0.51400
# [600]	train-rmse:7.84562	validation-rmse:8.26672	train-r2:0.62836	validation-r2:0.51421
# [610]	train-rmse:7.82215	validation-rmse:8.26580	train-r2:0.63058	validation-r2:0.51432
# [620]	train-rmse:7.80022	validation-rmse:8.26899	train-r2:0.63265	validation-r2:0.51394
# [630]	train-rmse:7.77758	validation-rmse:8.26857	train-r2:0.63477	validation-r2:0.51399
# [640]	train-rmse:7.75668	validation-rmse:8.26611	train-r2:0.63674	validation-r2:0.51428
# [650]	train-rmse:7.72877	validation-rmse:8.27066	train-r2:0.63935	validation-r2:0.51375
# Stopping. Best iteration:
# [605]	train-rmse:7.83263	validation-rmse:8.26494	train-r2:0.62959	validation-r2:0.51442
#
# [00:56:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
#    ID           y
# 0   1   82.515434
# 1   2   97.188736
# 2   3   82.554169
# 3   4   76.552170
# 4   5  112.846581
